# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts

# %%
# %matplotlib notebook

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### (a)

# %%
dt = np.loadtxt("incomes.txt")
fig, ax = plt.subplots()
ax.hist(dt, normed = True, bins= 30)
ax.set(title = "Distribution of Annual Income of MACSS students", 
       xlabel = "Annual Income", 
        ylabel = "Density")
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.text.Text at 0x11db41e48>,
#  <matplotlib.text.Text at 0x11d1d4828>,
#  <matplotlib.text.Text at 0x11db68208>]
